# %% [markdown]
# # 2. 출생아 및 합계 출산율

# %%
import pandas as pd
file_name = '506101_20230327202814940_excel.xlsx'
df= pd.read_excel(file_name, skiprows= 2, nrows=2, index_col =0)
# df= pd.read_excel(file_name, skiprows= 2, nrows=2, index_col =0)
df
# Out:
#           2011   2012    2013    2014    2015    2016    2017    2018    2019  \
# 합계출산율     1.24    1.3    1.19    1.21    1.24    1.17    1.05    0.98    0.92
# 출생아  수  471.00  484.0  436.50  435.40  438.40  406.20  357.00  326.00  302.00
#
#           2020    2021    2022
# 합계출산율     0.84    0.81    0.78
# 출생아  수  272.00  200.00  180.00

# %%
df.loc['합계출산율']
# Out:
# 2011    1.24
# 2012    1.30
# 2013    1.19
# 2014    1.21
# 2015    1.24
# 2016    1.17
# 2017    1.05
# 2018    0.98
# 2019    0.92
# 2020    0.84
# 2021    0.81
# 2022    0.78
# Name: 합계출산율, dtype: float64

# %%
df.index.values
# Out:
# array(['합계출산율', '출생아  수'], dtype=object)

# %%
df.index
# Out:
# Index(['합계출산율', '출생아  수'], dtype='object')

# %%
df.rename(index = {'합계출산율': '합계출산율', '출생아  수': '출생아 수'}, inplace = True)
df
# Out:
#          2011   2012    2013    2014    2015    2016    2017    2018    2019  \
# 합계출산율    1.24    1.3    1.19    1.21    1.24    1.17    1.05    0.98    0.92
# 출생아 수  471.00  484.0  436.50  435.40  438.40  406.20  357.00  326.00  302.00
#
#          2020    2021    2022
# 합계출산율    0.84    0.81    0.78
# 출생아 수  272.00  200.00  180.00

# %%
df.loc['출생아 수']

# df.loc['합계출산율']은 df.iloc[0] 이랑 같은 것!
# iloc = integer location
# Out:
# 2011    471.0
# 2012    484.0
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.0
# 2018    326.0
# 2019    302.0
# 2020    272.0
# 2021    200.0
# 2022    180.0
# Name: 출생아 수, dtype: float64

# %%
df
# Out:
#          2011   2012    2013    2014    2015    2016    2017    2018    2019  \
# 합계출산율    1.24    1.3    1.19    1.21    1.24    1.17    1.05    0.98    0.92
# 출생아 수  471.00  484.0  436.50  435.40  438.40  406.20  357.00  326.00  302.00
#
#          2020    2021    2022
# 합계출산율    0.84    0.81    0.78
# 출생아 수  272.00  200.00  180.00

# %%
df= df.T 
df
# Out:
#       합계출산율  출생아 수
# 2011   1.24  471.0
# 2012   1.30  484.0
# 2013   1.19  436.5
# 2014   1.21  435.4
# 2015   1.24  438.4
# 2016   1.17  406.2
# 2017   1.05  357.0
# 2018   0.98  326.0
# 2019   0.92  302.0
# 2020   0.84  272.0
# 2021   0.81  200.0
# 2022   0.78  180.0

# %% [markdown]
# # 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' 
matplotlib.rcParams['font.size'] = 15 #글자크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글폰트 사용시 마이너스 글자 깨짐 해결

# %%
plt.plot(df.index, df['합계출산율'], df['출생아 수'])

# %%
plt.plot(df.index, df['합계출산율'])
plt.plot(df.index, df['출생아 수'])

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
ax1.plot(df.index, df['출생아 수'], color = '#ffd100')
ax2= ax1.twinx() #x 축을 공유하는 쌍둥이 axis 
ax2.plot(df.index, df['합계출산율'], color = '#ff812d')

# %%
fig, ax1 = plt.subplots(figsize=(13,5))
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(250,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = '#ff812d')


ax2= ax1.twinx() #x 축을 공유하는 쌍둥이 axis 
ax2.set_ylabel('합계출산율')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계출산율'], color = '#ffd100')

# %%
fig, ax1 = plt.subplots(figsize=(13,5))
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(150,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = '#ff812d')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val+ 12, val, ha='center')


ax2= ax1.twinx() #x 축을 공유하는 쌍둥이 axis 
ax2.set_ylabel('합계출산율')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계출산율'], color = '#ffd100')

# %%
fig, ax1 = plt.subplots(figsize=(13,5))
# 서브플랏 이용시 타이틀은 슈퍼타이틀임
fig.suptitle('출생아 수 및 합계 출산율')
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(150,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = '#ff812d')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val+ 12, val, ha='center')


ax2= ax1.twinx() #x 축을 공유하는 쌍둥이 axis 
ax2.set_ylabel('합계출산율')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계출산율'], color = '#ffd100', marker='o', ms = 15, lw=2, mec='w', mew=3)

for idx, val in enumerate(df['합계출산율']):
    ax2.text(idx, val+0.08, val, ha='center')
